# %% [markdown]
# <a href="https://colab.research.google.com/github/UdariAdhikaram/First-project/blob/main/Image_Filtering_(Convolution).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
im = cv2.imread("/content/sample_data/lenna-png-1.png")

# %%
im.shape

(512, 512, 3)
# Out:
# (512, 512, 3)

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im.shape
(512, 512)
# Out:
# (512, 512)

# %%
v_kernel = np.array([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1],
])

# %%
v_image = cv2.filter2D(im, -1, v_kernel)

# %%
plt.imshow(im, cmap= 'gray')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='gray')
plt.title('Vertical Image')
# Out:
# Text(0.5, 1.0, 'vertical Image')
