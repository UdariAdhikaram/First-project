# %% [markdown]
# <a href="https://colab.research.google.com/github/UdariAdhikaram/First-project/blob/main/Copy_of_1D_Convolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
signal = np.array([1, 1, 1, 1, 1, 1, 1, 0.5, 0.5, 0.5])

# %%
plt.stem(signal)
plt.show()
